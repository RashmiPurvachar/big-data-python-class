# %% [markdown]
# # Homework 3  - Tryout pandas and numpy
#
# Copy this notebook. Rename it as: YOURNAME-Homework-panda-numpy-Sept-2017
#
# with your name replacing yourname and  replaced with the date you submit or to the last part.
#
# Do the homeworks problems below.
#
# Upload your completed jupyter notebook to your github site and send me the url via the elearning site as your homework submission. Please note that you need to do your own 3.4, and 3.5 if you share data and analysis from others then you cannot get more than a 3.

# %% [markdown]
# ## Homework 3.1
#
# ### 3.1.a
# Load the data from: http://opendata.dc.gov/datasets that I have include in this github
# into a dataframe.  ( The file has been is available in directory ./data/ccp_current_csv.csv )

# %%
import pandas as pd
import numpy as np

mydata = pd.read_csv("./data/ccp_current_csv.csv")
mydata
# Out:
#                  STREET QUADRANT            FROMINTERSECTION  \
# 0               13th St       NW                  Kennedy St
# 1                  S St       NW            North Capitol St
# 2      Rhode Island Ave       NE            Brentwood Rd (W)
# 3               Mill Rd       NW                     27th St
# 4      Rhode Island Ave       NE            Brentwood Rd (M)
# 5             Mellon St       SE                      5th St
# 6          Nebraska Ave       NW              Northampton St
# 7           Military Rd       NW                     30th St
# 8          Nebraska Ave       NW                   Oliver St
# 9               16th St       NW                  Alaska Ave
# 10         Shoemaker St       NW                 Linnean Ave
# 11         Underwood St       NW             Piney Branch Rd
# 12             Elder St       NW                      7th St
# 13              26th St       NW              Northampton St
# ...

# %% [markdown]
# ### 3.1.a  what is its shape and what does that mean?

# %%
shape = mydata.shape
print(shape)
print(type(shape))
# Out:
# (465, 27)
# <type 'tuple'>

# %% [markdown]
# ## Homework 3.2
#  What are the number of rows in each 'QUADRANT' ?

# %%
# to return the length
print(len(mydata.index))

#to return count 'of number of rows' in each Quadrant
mydata['QUADRANT'].value_counts()
# Out:
# 465
# NW    195
# NE    163
# SE     84
# BN     12
# SW     11
# Name: QUADRANT, dtype: int64

# %% [markdown]
# ## Homework 3.3 - Array math demonstration
# For two arrarys
#
# a= [1,2,3,4]  type=float
#
# b= [5,6,7,8]  type=float
#
# Peform the following array operations using numpy
# ( show both operational use of numpy and functional (example addition operation => + vs addition function => numbpy.add() )
#
# ### 3.3.1 addition a+b

# %%
a = np.array([1,2,3,4],dtype=float)
b = np.array([5,6,7,8],dtype=float)

# addition operation
print (a+b) 

# addition functional
print (np.add(a,b))
# Out:
# [ 6.  8. 10. 12.]
# [ 6.  8. 10. 12.]

# %% [markdown]
# ### 3.3.2 subtraction a-b

# %%
# subtraction operation
print (a-b) 

# subtraction functional
print (np.subtract(a,b))
# Out:
# [-4. -4. -4. -4.]
# [-4. -4. -4. -4.]

# %% [markdown]
# ### 3.3.3 multiplication a*b

# %%
# multiplication operation
print (a*b) 

# multiplication functional
print (np.multiply(a,b))
# Out:
# [ 5. 12. 21. 32.]
# [ 5. 12. 21. 32.]

# %% [markdown]
# ### 3.3.4 divsion a/b

# %%
# division operation
print (a/b) 

# division functional
print (np.divide(a,b))
# Out:
# [0.2        0.33333333 0.42857143 0.5       ]
# [0.2        0.33333333 0.42857143 0.5       ]

# %% [markdown]
# ### 3.3.5 modulo  a%b

# %%
# modulo operation
print (a%b) 

# modulo functional
print (np.mod(a,b))
# Out:
# [1. 2. 3. 4.]
# [1. 2. 3. 4.]

# %% [markdown]
# ### 3.3.6 power  a^b

# %%
# power operation
print (a**b) 

# power functional
print (np.power(a,b))
# Out:
# [1.0000e+00 6.4000e+01 2.1870e+03 6.5536e+04]
# [1.0000e+00 6.4000e+01 2.1870e+03 6.5536e+04]

# %% [markdown]
# ### 3.3.7 Other Math functions

# %% [markdown]
# **Square root**

# %%
# squareroot operation
print(np.sqrt(a))
print(np.sqrt(b))
# Out:
# [1.         1.41421356 1.73205081 2.        ]
# [2.23606798 2.44948974 2.64575131 2.82842712]

# %% [markdown]
# **Absolute value**

# %%
# absolute function
print np.absolute(a)
print np.absolute(b)
# Out:
# [1. 2. 3. 4.]

# %% [markdown]
# **Statistics**

# %%
print a.mean()
## or print np.mean(a)

print np.median(a)

print a.std()
# Out:
# 2.5
# 2.5
# 1.118033988749895

# %% [markdown]
# **Cross Product**
#
# The cross product or vector product is a binary operation on two vectors in three-dimensional space.
#
# The result is a vector which is perpendicular to the vectors being multiplied and normal to the plane containing them.
#
# The cross product of two vectors a and b is denoted by x × y

# %%
# cross product
x = np.array([0,0,1])
y = np.array([0,1,0])
print np.cross(x,y)
print np.cross(y,x)
# Out:
# [-1  0  0]
# [1 0 0]

# %% [markdown]
# **Scalar Operations**

# %%
print b + 1
print 2**a
# Out:
# [6. 7. 8. 9.]
# [ 2.  4.  8. 16.]

# %% [markdown]
# **Array comparisions**

# %%
i = np.array([1, 2, 3, 4])
j = np.array([4, 2, 2, 4])
print i == j

print i > j
# Out:
# [False  True False  True]
# [False False  True False]

# %%
k = np.zeros((100, 100))
print np.any(k != 0)
print np.all(a == a)
# Out:
# False
# True

# %% [markdown]
# **Logical Operations**

# %%
m = np.array([1, 1, 0, 0], dtype=bool)
n = np.array([1, 0, 1, 0], dtype=bool)
print np.logical_or(m, n)
print np.logical_and(m, n)
print np.all([True, True, False])
print np.any([True, True, False])
# Out:
# [ True  True  True False]
# [ True False False False]
# False
# True

# %% [markdown]
# **Transcendental functions**

# %%
t = np.arange(4)
print np.sin(t)
print np.cos(t)
print np.tan(t)
print np.log(t)
print np.exp(t)
# Out:
# [0.         0.84147098 0.90929743 0.14112001]
# [ 1.          0.54030231 -0.41614684 -0.9899925 ]
# [ 0.          1.55740772 -2.18503986 -0.14254654]
# [      -inf 0.         0.69314718 1.09861229]
# [ 1.          2.71828183  7.3890561  20.08553692]
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """

# %% [markdown]
# **Basic Reductions**

# %%
r = np.array([1, 2, 3, 4, 5])
# to return the sum of all elements
print r.sum()
# or print np.add.reduce(r)

# to return the product of all elements
print np.multiply.reduce(r)

# to return the minimum value of all elements
print r.min()

# to return the maximum value of all elements
print r.max()

# to return the index of the minimum value of all elements
print r.argmin()

# to return the index of the maximum value of all elements
print r.argmax()
# Out:
# 15
# 120
# 1
# 5
# 0
# 4

# %% [markdown]
# **Boolean Indexing**

# %%
q = np.array([23,60,1976,100,89])
print(q == 100)
print(q > 50)
# Out:
# [False False False  True False]
# [False  True  True  True  True]

# %% [markdown]
# **References**
#
# http://www.scipy-lectures.org/intro/numpy/operations.html
#
# https://www.tutorialspoint.com/numpy/numpy_array_from_numerical_ranges.htm
#
# https://www.python-course.eu/matrix_arithmetic.php

# %% [markdown]
# ## Homework 3.4
# Find your own data and load it into a dataframe
#
# One of IBM sample data sets of a telephone company, from www.kaggle.com

# %%
# To predict behavior to retain customers, analyze all relevant customer data 
# and develop focused customer retention programs.
my_telco_data = pd.read_csv("./data/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# to visualize the first few rows on our DataFrame, the default value is 5.
my_telco_data.head()

# df.tail(n=5), to return the last 5 rows on our DataFrame
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 1                No             DSL            Yes  ...               Yes
# 2                No             DSL            Yes  ...                No
# 3  No phone service             DSL            Yes  ...               Yes
# 4                No     Fiber optic             No  ...                No
#
# ...

# %%
# to return the column names
my_telco_data.columns
# Out:
# Index([u'customerID', u'gender', u'SeniorCitizen', u'Partner', u'Dependents',
#        u'tenure', u'PhoneService', u'MultipleLines', u'InternetService',
#        u'OnlineSecurity', u'OnlineBackup', u'DeviceProtection', u'TechSupport',
#        u'StreamingTV', u'StreamingMovies', u'Contract', u'PaperlessBilling',
#        u'PaymentMethod', u'MonthlyCharges', u'TotalCharges', u'Churn'],
#       dtype='object')

# %%
# to return a quick statistic summary of data, only the numeric columns
my_telco_data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# ## Homework 3.5
# Provide an interesting analysis of the data columns ( frequency or averages )

# %% [markdown]
# ### 3.5.1 Selecting Data

# %%
# to return the first 5 data values from column 'customerID'
my_telco_data.customerID.head()

# or
# my_telco_data['customerID'].head()
# Out:
# 0    7590-VHVEG
# 1    5575-GNVDE
# 2    3668-QPYBK
# 3    7795-CFOCW
# 4    9237-HQITU
# Name: customerID, dtype: object

# %%
# Slicing the rows using '[]' to select the data
my_telco_data[0:2]
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 1                No             DSL            Yes  ...               Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# 0  Electronic check          29.85         29.85    No
# 1      Mailed check          56.95        1889.5    No
#
# [2 rows x 21 columns]

# %%
# to return a particular value from a row, use 'at'
my_telco_data.at[1,'customerID']
# Out:
# '5575-GNVDE'

# %% [markdown]
# **Selecting using 'loc' property**
#
# loc property takes two arguments,
#
# -  The first is the indexes of the slices, none defined here indicates that there isn’t any row slicing
# -  The second is the name(s) of the columns we desire to slice.

# %%
# to return data on selected columns 
my_telco_data.loc[:,['customerID','PaymentMethod','TotalCharges']].head(10)
# Out:
#    customerID              PaymentMethod TotalCharges
# 0  7590-VHVEG           Electronic check        29.85
# 1  5575-GNVDE               Mailed check       1889.5
# 2  3668-QPYBK               Mailed check       108.15
# 3  7795-CFOCW  Bank transfer (automatic)      1840.75
# 4  9237-HQITU           Electronic check       151.65
# 5  9305-CDSKC           Electronic check        820.5
# 6  1452-KIOVK    Credit card (automatic)       1949.4
# 7  6713-OKOMC               Mailed check        301.9
# 8  7892-POOKP           Electronic check      3046.05
# 9  6388-TABGU  Bank transfer (automatic)      3487.95

# %%
# to return required data by selecting the columns and slicing the rows
my_telco_data.loc[0:7,['customerID','PaymentMethod','TotalCharges']]
# Out:
#    customerID              PaymentMethod TotalCharges
# 0  7590-VHVEG           Electronic check        29.85
# 1  5575-GNVDE               Mailed check       1889.5
# 2  3668-QPYBK               Mailed check       108.15
# 3  7795-CFOCW  Bank transfer (automatic)      1840.75
# 4  9237-HQITU           Electronic check       151.65
# 5  9305-CDSKC           Electronic check        820.5
# 6  1452-KIOVK    Credit card (automatic)       1949.4
# 7  6713-OKOMC               Mailed check        301.9

# %%
# selecting multiple columns and rows
my_telco_data.loc[1156:1158,['customerID','PhoneService','InternetService']]
# Out:
#       customerID PhoneService InternetService
# 1156  0621-CXBKL          Yes              No
# 1157  5268-DSMNQ          Yes     Fiber optic
# 1158  5334-JLAXU          Yes     Fiber optic

# %% [markdown]
# ### 3.5.2 Booloean Indexing
#
# As Panda supports Boolean indexing, it is possible to filter out data from a dataframe based on the value of a column

# %%
# to return the data of all senior citizens
my_telco_data[my_telco_data.SeniorCitizen == 1]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 20    8779-QRDMV    Male              1      No         No       1
# 30    3841-NFECX  Female              1     Yes         No      71
# 31    4929-XIHVW    Male              1     Yes         No       2
# 34    3413-BMNZE    Male              1      No         No       1
# 50    8012-SOUDQ  Female              1      No         No      43
# 52    6575-SUVOI  Female              1     Yes         No      25
# 53    7495-OOKFY  Female              1     Yes         No       8
# 54    4667-QONEA  Female              1     Yes        Yes      60
# 55    1658-BYGOY    Male              1      No         No      18
# 57    5067-XJQFU    Male              1     Yes        Yes      66
# 72    1891-QRQSA    Male              1     Yes        Yes      64
# 75    2673-CXQEU  Female              1      No         No      56
# 78    0191-ZHSKZ    Male              1      No         No      30
# ...

# %%
# to return values filtering on multiple values, using the builtin function df.isin()
my_telco_data[my_telco_data['PaymentMethod'].isin(['Mailed check','Electronic check'])]

# my_telco_data[my_telco_data['Contract'].isin(['One year','Two year'])]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 14    5129-JLPIS    Male              0      No         No      25
# 16    8191-XWSZG  Female              0      No         No      52
# 19    4183-MYFRB  Female              0      No         No      21
# 20    8779-QRDMV    Male              1      No         No       1
# 22    1066-JKSGK    Male              0      No         No       1
# ...

# %% [markdown]
# ### 3.5.3 Column operations
#
# **Derving a new column from existing**
#
# New columns can be derived from an existing dataset to count, compare values and help analyze the data

# %%
# to return the count against a column value
my_telco_data['PaymentMethod'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %% [markdown]
# **Creating a new column**
#
# Creating a column is much like creating a new key-value pair in a dictionary.
# By assigning values to the new column name, you add a column to the DataFrame
#
# New column(s) created will be added to the end of the column set(extreme right).

# %%
# creating new column
my_telco_data['new_column'] = "Unknown Value"
my_telco_data.loc[0:3,['customerID','new_column']]
# Out:
#    customerID     new_column
# 0  7590-VHVEG  Unknown Value
# 1  5575-GNVDE  Unknown Value
# 2  3668-QPYBK  Unknown Value
# 3  7795-CFOCW  Unknown Value

# %% [markdown]
# **Replacing values in a column**

# %%
# to rename a column, .replace property is used
my_telco_data.replace("Unknown Value", np.nan).head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity    ...     TechSupport  \
# 0  No phone service             DSL             No    ...              No
# 1                No             DSL            Yes    ...              No
# 2                No             DSL            Yes    ...              No
# 3  No phone service             DSL            Yes    ...             Yes
# 4                No     Fiber optic             No    ...              No
#
# ...

# %% [markdown]
# **Renaming a Column**

# %%
# to rename a column, .rename property is used
my_telco_data.rename(columns ={"new_column": "dummy_column"}, inplace=True)
my_telco_data.loc[0:3,['customerID','dummy_column']]
# Out:
#    customerID   dummy_column
# 0  7590-VHVEG  Unknown Value
# 1  5575-GNVDE  Unknown Value
# 2  3668-QPYBK  Unknown Value
# 3  7795-CFOCW  Unknown Value

# %%
# to return sample data
my_telco_data.sample(n=4)
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 5638  5143-WMWOG   Male              0      No         No       1
# 3166  9097-ZUBYC   Male              0     Yes         No      14
# 3493  5968-VXZLG   Male              0      No         No       2
# 5939  4712-AUQZO   Male              0      No         No      18
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 5638          Yes                No              No  No internet service
# 3166          Yes                No             DSL                   No
# 3493          Yes                No             DSL                   No
# 5939           No  No phone service             DSL                  Yes
#
#           ...                TechSupport          StreamingTV  \
# 5638      ...        No internet service  No internet service
# 3166      ...                        Yes                   No
# 3493      ...                         No                   No
# ...

# %%
# to return the sorted dataframe in the defined order
my_telco_data.sort_values(by='customerID', ascending=False)[0:5]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1634  9995-HOTOH    Male              0     Yes        Yes      63
# 1996  9993-LHIEB    Male              0     Yes        Yes      67
# 1260  9992-UJOEL    Male              0      No         No       2
# 2875  9992-RRAMN    Male              0     Yes         No      22
# 3607  9987-LUTYD  Female              0      No         No      13
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 1634           No  No phone service             DSL            Yes
# 1996          Yes                No             DSL            Yes
# 1260          Yes                No             DSL             No
# 2875          Yes               Yes     Fiber optic             No
# 3607          Yes                No             DSL            Yes
#
#           ...       TechSupport StreamingTV StreamingMovies        Contract  \
# 1634      ...                No         Yes             Yes        Two year
# ...

# %% [markdown]
# ### 3.5.5 Summary functions

# %%
# to return - number of rows in the dataset
my_telco_data['customerID'].count()
# Out:
# 7043

# %%
# to return - maximum 'tenure' 
my_telco_data['tenure'].max()
# Out:
# 72

# %%
# to return - the total sum of monthly payment done through mailed check
my_telco_data['MonthlyCharges'][my_telco_data['PaymentMethod'] == 'Mailed check'].sum()
# Out:
# 70794.3

# %%
# to return - the count on Internet services
my_telco_data['InternetService'].value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %%
# to return - Number of non-null unique Contract entries
my_telco_data['Contract'].nunique()
# Out:
# 3

# %% [markdown]
# ### 3.5.6 Groupby : Split, Apply and Combine
#
# Any groupby operation involves one of the following operations on the original object,
#
# -  Splitting the Object
#
# -  Applying a function
#
# -  Combining the results
#
# In the apply functionality, we can perform the following operations,
#
# -  Aggregation − computing a summary statistic
#
# -  Transformation − perform some group-specific operation
#
# -  Filtration − discarding the data with some condition
#
# **Step 1:** split the data into groups by creating a groupby object from the original DataFrame

# %%
# Group by column 'Contract'
my_telco_data_by_contract = my_telco_data.groupby('Contract')

# check type of groupby object 
type(my_telco_data_by_contract)
# Out:
# pandas.core.groupby.groupby.DataFrameGroupBy

# %% [markdown]
# **Step 2:** apply 'describe' function

# %%
my_telco_data_by_contract.describe().head()
# Out:
#                MonthlyCharges                                              \
#                         count       mean        std    min     25%    50%
# Contract
# Month-to-month         3875.0  66.398490  26.926599  18.75  45.850  73.25
# One year               1473.0  65.048608  31.840539  18.25  26.900  68.75
# Two year               1695.0  60.770413  34.678865  18.40  24.025  64.35
#
#                                SeniorCitizen            ...             \
#                    75%     max         count      mean  ...   75%  max
# Contract                                                ...
# Month-to-month  88.875  117.45        3875.0  0.208258  ...   0.0  1.0
# One year        94.800  118.60        1473.0  0.128988  ...   0.0  1.0
# Two year        90.450  118.75        1695.0  0.085546  ...   0.0  1.0
#
#                 tenure
#                  count       mean        std  min   25%   50%   75%   max
# Contract
# ...

# %% [markdown]
# **Step 3:** combine the results into a new DataFrame.

# %%
my_telco_data_by_contract_median = my_telco_data_by_contract.median()
my_telco_data_by_contract_median.head()
# Out:
#                 SeniorCitizen  tenure  MonthlyCharges
# Contract
# Month-to-month              0      12           73.25
# One year                    0      44           68.75
# Two year                    0      64           64.35

# %% [markdown]
# **Selecting a single group**
#
# get_group() method is used to select a single group.

# %%
grouped = my_telco_data.groupby('PaymentMethod')
print grouped.get_group('Electronic check')
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 8     7892-POOKP  Female              0     Yes         No      28
# 14    5129-JLPIS    Male              0      No         No      25
# 19    4183-MYFRB  Female              0      No         No      21
# 20    8779-QRDMV    Male              1      No         No       1
# 26    6467-CHFZW    Male              0     Yes        Yes      47
# 27    8665-UTDHZ    Male              0     Yes        Yes       1
# 36    6047-YHPVI    Male              0      No         No       5
# 38    5380-WJKOV    Male              0      No         No      34
# 44    4080-IIARD  Female              0     Yes         No      13
# 45    3714-NTNFO  Female              0      No         No      49
# ...

# %% [markdown]
# **Aggregations**
#
# An aggregated function returns a single aggregated value for each group. Once the group by object is created, several aggregation operations can be performed on the grouped data using 'agg()' method.

# %%
# to return the mean of the 'tenure' grouped by 'Internet Service'
grouped = my_telco_data.groupby('InternetService')
print grouped['tenure'].agg(np.mean)
# Out:
# InternetService
# DSL            32.821561
# Fiber optic    32.917959
# No             30.547182
# Name: tenure, dtype: float64

# %%
# to return the size of the 'tenure' grouped by 'Internet Service'
grouped = my_telco_data.groupby('InternetService')
print grouped['tenure'].agg(np.size)
# Out:
# InternetService
# DSL            2421
# Fiber optic    3096
# No             1526
# Name: tenure, dtype: int64

# %%
# using multiple aggregation functions at once
grouped = my_telco_data.groupby('InternetService')
print grouped['tenure'].agg([np.sum, np.mean, np.std])
# Out:
#                     sum       mean        std
# InternetService
# DSL               79461  32.821561  24.812178
# Fiber optic      101914  32.917959  24.425332
# No                46615  30.547182  24.356507

# %% [markdown]
# **References**
#
# https://codeburst.io/getting-started-with-data-analysis-in-python-2aaa4dbedd46
#
# https://community.modeanalytics.com/python/tutorial/defining-python-functions/
#
# https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/
